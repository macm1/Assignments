# %%
import pandas as pd
import numpy as  np
import matplotlib.pyplot as plt
import seaborn as sns
 
import warnings 
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = 300

sns.set_theme(style='darkgrid')

# %matplotlib inline

# %% [markdown]
# # Q2 →→→ANS→→→Hierarchical

# %%
df = pd.read_csv(r"C:\Users\mange\OneDrive\Documents\DS\Assignmnet_Material\Clustering\Airlines.csv")
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df.drop(columns=['ID#'] ,inplace=True)
df
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Balance            3999 non-null   int64
#  1   Qual_miles         3999 non-null   int64
#  2   cc1_miles          3999 non-null   int64
#  3   cc2_miles          3999 non-null   int64
#  4   cc3_miles          3999 non-null   int64
#  5   Bonus_miles        3999 non-null   int64
#  6   Bonus_trans        3999 non-null   int64
#  7   Flight_miles_12mo  3999 non-null   int64
#  8   Flight_trans_12    3999 non-null   int64
#  9   Days_since_enroll  3999 non-null   int64
#  10  Award?             3999 non-null   int64
# dtypes: int64(11)
# memory usage: 343.8 KB

# %%
df[df.duplicated()]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 3876     1000           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 3876            0                  0                0               1597
#
#       Award?
# 3876       0

# %%
df.drop(index=[3876] , inplace=True)
df
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc= StandardScaler()

x = sc.fit_transform(df)
x
# Out:
# array([[-4.51293870e-01, -1.86322793e-01, -7.69731660e-01, ...,
#         -3.62219103e-01,  1.39523468e+00, -7.67071631e-01],
#        [-5.39604653e-01, -1.86322793e-01, -7.69731660e-01, ...,
#         -3.62219103e-01,  1.37973643e+00, -7.67071631e-01],
#        [-3.20192202e-01, -1.86322793e-01, -7.69731660e-01, ...,
#         -3.62219103e-01,  1.41170157e+00, -7.67071631e-01],
#        ...,
#        [-2.23153612e-04, -1.86322793e-01,  6.82893866e-01, ...,
#         -3.62219103e-01, -1.31599028e+00,  1.30365921e+00],
#        [-1.85776026e-01, -1.86322793e-01, -7.69731660e-01, ...,
#         -9.85832074e-02, -1.31647460e+00, -7.67071631e-01],
#        [-7.00646048e-01, -1.86322793e-01, -7.69731660e-01, ...,
#         -3.62219103e-01, -1.31792757e+00, -7.67071631e-01]])

# %%
from sklearn.preprocessing import normalize

# %%
df = pd.DataFrame(normalize(df), columns= df.columns)
df
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.970414         0.0   0.000034   0.000034   0.000034     0.006000
# 1     0.940209         0.0   0.000049   0.000049   0.000049     0.010504
# 2     0.981113         0.0   0.000024   0.000024   0.000024     0.097817
# 3     0.904428         0.0   0.000061   0.000061   0.000061     0.030605
# 4     0.912226         0.0   0.000037   0.000009   0.000009     0.404078
# ...        ...         ...        ...        ...        ...          ...
# 3993  0.905810         0.0   0.000049   0.000049   0.000049     0.417949
# 3994  0.999649         0.0   0.000016   0.000016   0.000016     0.015231
# 3995  0.944948         0.0   0.000039   0.000013   0.000013     0.326726
# 3996  0.999592         0.0   0.000018   0.000018   0.000018     0.009104
# 3997  0.907271         0.0   0.000301   0.000301   0.000301     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
from scipy.cluster import hierarchy

# %%
lk = hierarchy.linkage(df , method= 'complete')
dendrogram = hierarchy.dendrogram(lk)

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
ag = AgglomerativeClustering(n_clusters=5)

ypred  = ag.fit_predict(df)
ypred
# Out:
# array([4, 2, 2, ..., 2, 4, 2], dtype=int64)

# %%
df['cluster'] = ypred
df
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.970414         0.0   0.000034   0.000034   0.000034     0.006000
# 1     0.940209         0.0   0.000049   0.000049   0.000049     0.010504
# 2     0.981113         0.0   0.000024   0.000024   0.000024     0.097817
# 3     0.904428         0.0   0.000061   0.000061   0.000061     0.030605
# 4     0.912226         0.0   0.000037   0.000009   0.000009     0.404078
# ...        ...         ...        ...        ...        ...          ...
# 3993  0.905810         0.0   0.000049   0.000049   0.000049     0.417949
# 3994  0.999649         0.0   0.000016   0.000016   0.000016     0.015231
# 3995  0.944948         0.0   0.000039   0.000013   0.000013     0.326726
# 3996  0.999592         0.0   0.000018   0.000018   0.000018     0.009104
# 3997  0.907271         0.0   0.000301   0.000301   0.000301     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
df['cluster'].value_counts()
# Out:
# cluster
# 2    1547
# 4    1191
# 3     579
# 1     453
# 0     228
# Name: count, dtype: int64

# %%
df.groupby('cluster').agg('mean')
# Out:
#           Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# cluster
# 0        0.653406    0.000987   0.000201   0.000201   0.000201     0.080253
# 1        0.560544    0.002134   0.000094   0.000052   0.000051     0.755052
# 2        0.964396    0.001987   0.000046   0.000035   0.000035     0.184097
# 3        0.877981    0.002331   0.000059   0.000028   0.000027     0.460445
# 4        0.992808    0.005247   0.000039   0.000038   0.000038     0.028459
#
#          Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# cluster
# 0           0.000383           0.006382         0.000024           0.679217
# 1           0.000516           0.017330         0.000055           0.149671
# 2           0.000303           0.008423         0.000024           0.116522
# 3           0.000384           0.005802         0.000019           0.079691
# 4           0.000074           0.004966         0.000018           0.080081
#
#            Award?
# cluster
# ...

# %%
df
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.970414         0.0   0.000034   0.000034   0.000034     0.006000
# 1     0.940209         0.0   0.000049   0.000049   0.000049     0.010504
# 2     0.981113         0.0   0.000024   0.000024   0.000024     0.097817
# 3     0.904428         0.0   0.000061   0.000061   0.000061     0.030605
# 4     0.912226         0.0   0.000037   0.000009   0.000009     0.404078
# ...        ...         ...        ...        ...        ...          ...
# 3993  0.905810         0.0   0.000049   0.000049   0.000049     0.417949
# 3994  0.999649         0.0   0.000016   0.000016   0.000016     0.015231
# 3995  0.944948         0.0   0.000039   0.000013   0.000013     0.326726
# 3996  0.999592         0.0   0.000018   0.000018   0.000018     0.009104
# 3997  0.907271         0.0   0.000301   0.000301   0.000301     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
sns.scatterplot(x = df['Balance'] , y = df['cluster']  , hue=df['cluster'] , palette= 'rainbow')
# Out:
# <Axes: xlabel='Balance', ylabel='cluster'>

# %% [markdown]
# # Q2 →→→ANS→→→DBSCAN

# %%
air = pd.read_csv(r"C:\Users\mange\OneDrive\Documents\DS\Assignmnet_Material\Clustering\Airlines.csv")
air
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
air.drop(columns=['ID#'] , inplace= True)
air
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
air.describe()
# Out:
#             Balance    Qual_miles    cc1_miles    cc2_miles    cc3_miles  \
# count  3.999000e+03   3999.000000  3999.000000  3999.000000  3999.000000
# mean   7.360133e+04    144.114529     2.059515     1.014504     1.012253
# std    1.007757e+05    773.663804     1.376919     0.147650     0.195241
# min    0.000000e+00      0.000000     1.000000     1.000000     1.000000
# 25%    1.852750e+04      0.000000     1.000000     1.000000     1.000000
# 50%    4.309700e+04      0.000000     1.000000     1.000000     1.000000
# 75%    9.240400e+04      0.000000     3.000000     1.000000     1.000000
# max    1.704838e+06  11148.000000     5.000000     3.000000     5.000000
#
#          Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# count    3999.000000   3999.00000        3999.000000      3999.000000
# mean    17144.846212     11.60190         460.055764         1.373593
# std     24150.967826      9.60381        1400.209171         3.793172
# ...

# %%
air.shape
# Out:
# (3999, 11)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

x = sc.fit_transform(air)
x
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
from sklearn.preprocessing import normalize

# %%
air = pd.DataFrame(normalize(air) , columns=air.columns)
air
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.970414         0.0   0.000034   0.000034   0.000034     0.006000
# 1     0.940209         0.0   0.000049   0.000049   0.000049     0.010504
# 2     0.981113         0.0   0.000024   0.000024   0.000024     0.097817
# 3     0.904428         0.0   0.000061   0.000061   0.000061     0.030605
# 4     0.912226         0.0   0.000037   0.000009   0.000009     0.404078
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.905810         0.0   0.000049   0.000049   0.000049     0.417949
# 3995  0.999649         0.0   0.000016   0.000016   0.000016     0.015231
# 3996  0.944948         0.0   0.000039   0.000013   0.000013     0.326726
# 3997  0.999592         0.0   0.000018   0.000018   0.000018     0.009104
# 3998  0.907271         0.0   0.000301   0.000301   0.000301     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
from sklearn.cluster import DBSCAN

# %%
db = DBSCAN(eps=0.5  , min_samples=3)

y = db.fit_predict(df)
y
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import silhouette_score

# %%
x
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
y
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
silhouette_score(df, y)
# Out:
# 0.7915236092740233

# %%
air[air.duplicated()]
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 3876  0.530714         0.0   0.000531   0.000531   0.000531          0.0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 3876          0.0                0.0              0.0            0.84755
#
#       Award?
# 3876     0.0

# %%
air.drop(index=[3876] , inplace= True)
air
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.970414         0.0   0.000034   0.000034   0.000034     0.006000
# 1     0.940209         0.0   0.000049   0.000049   0.000049     0.010504
# 2     0.981113         0.0   0.000024   0.000024   0.000024     0.097817
# 3     0.904428         0.0   0.000061   0.000061   0.000061     0.030605
# 4     0.912226         0.0   0.000037   0.000009   0.000009     0.404078
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.905810         0.0   0.000049   0.000049   0.000049     0.417949
# 3995  0.999649         0.0   0.000016   0.000016   0.000016     0.015231
# 3996  0.944948         0.0   0.000039   0.000013   0.000013     0.326726
# 3997  0.999592         0.0   0.000018   0.000018   0.000018     0.009104
# 3998  0.907271         0.0   0.000301   0.000301   0.000301     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
air['cluster'] = y
air
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.970414         0.0   0.000034   0.000034   0.000034     0.006000
# 1     0.940209         0.0   0.000049   0.000049   0.000049     0.010504
# 2     0.981113         0.0   0.000024   0.000024   0.000024     0.097817
# 3     0.904428         0.0   0.000061   0.000061   0.000061     0.030605
# 4     0.912226         0.0   0.000037   0.000009   0.000009     0.404078
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.905810         0.0   0.000049   0.000049   0.000049     0.417949
# 3995  0.999649         0.0   0.000016   0.000016   0.000016     0.015231
# 3996  0.944948         0.0   0.000039   0.000013   0.000013     0.326726
# 3997  0.999592         0.0   0.000018   0.000018   0.000018     0.009104
# 3998  0.907271         0.0   0.000301   0.000301   0.000301     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
from sklearn.neighbors import NearestNeighbors

# %%
neigh = NearestNeighbors(n_neighbors= 5).fit(air)
neigh
# Out:
# NearestNeighbors()

# %%
d ,index = neigh.kneighbors(air)
d
# Out:
# array([[0.        , 0.00102256, 0.00368179, 0.0060018 , 0.00681951],
#        [0.        , 0.0033749 , 0.00633388, 0.00666874, 0.00973163],
#        [0.        , 0.00193076, 0.00672484, 0.0079254 , 0.00871483],
#        ...,
#        [0.        , 0.00559025, 0.00624011, 0.00637472, 0.00745858],
#        [0.        , 0.00167494, 0.00609868, 0.00641238, 0.00700177],
#        [0.        , 0.00173396, 0.00267189, 0.00403243, 0.00666753]])

# %%
distance = np.sort(d[:,1])
distance
# Out:
# array([1.12188742e-05, 1.12188742e-05, 1.75257452e-05, ...,
#        2.30528024e-01, 2.56025012e-01, 3.23915605e-01])

# %%
plt.plot(distance)
plt.xlabel('Distance')
plt.ylabel('EPS')
plt.title('K-Distance graph')
# Out:
# Text(0.5, 1.0, 'K-Distance graph')

# %%
plt.plot(distance)
plt.xlabel('Distance')
plt.ylabel('EPS')
plt.title('K-Distance graph')

plt.axhline(y = 0.05 , linestyle = '--' , color = 'red')

# %%
db = DBSCAN(eps=0.05 ,min_samples=5)

yp = db.fit_predict(air)
yp
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
silhouette_score(air , yp)
# Out:
# 0.34946643521177734

# %%
plt.scatter(air['cluster'],air['Balance'])
